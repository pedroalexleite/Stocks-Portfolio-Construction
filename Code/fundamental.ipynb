# %%
#PACKAGES

import pandas as pd
import yfinance as yf
import talib
import numpy as np
import requests
from io import StringIO
from datetime import date, datetime, timedelta
import praw
import emoji
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
#TICKERS

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {"User-Agent": "Mozilla/5.0"}
html = requests.get(url, headers=headers).text
sp500 = pd.read_html(StringIO(html))[0]
tickers = sp500['Symbol'].tolist()
ticker_map = {
    "BF.B": "BF-B",
    "BRK.B": "BRK-B"
}
tickers = [ticker_map.get(t, t) for t in tickers] 
tickers = sorted(tickers)

# %%
#VARIABLES

def calculate_variables(tickers):
    all_data = []

    for i, ticker in enumerate(tickers, 1):
        try:
            t = yf.Ticker(ticker)

            bs = t.quarterly_balance_sheet.T
            is_ = t.quarterly_income_stmt.T
            cf = t.quarterly_cashflow.T

            bs_cols = ['Total Assets', 'Total Stockholder Equity', 'Total Current Assets',
                       'Total Current Liabilities', 'Inventory', 'Cash', 'Total Debt']
            is_cols = ['Net Income', 'EBITDA', 'EBIT', 'Operating Income',
                       'Gross Profit', 'Total Revenue', 'Interest Expense', 'Research Development']
            cf_cols = ['Total Cash From Operating Activities', 'Capital Expenditures', 'Free Cash Flow']

            bs = bs[[c for c in bs_cols if c in bs.columns]]
            is_ = is_[[c for c in is_cols if c in is_.columns]]
            cf = cf[[c for c in cf_cols if c in cf.columns]]

            df = bs.join(is_, how="outer").join(cf, how="outer")
            df = df.tail(1)

            info = t.info
            info_fields = {
                "Current Price": info.get("currentPrice"),
                "Trailing Eps": info.get("trailingEps"),
                "Book Value": info.get("bookValue"),
                "Market Cap": info.get("marketCap"),
                "Enterprise Value": info.get("enterpriseValue"),
                "Dividend Yield": info.get("dividendYield"),
                "Shares Outstanding": info.get("sharesOutstanding"),
                "Earnings Growth": info.get("earningsGrowth"),
            }

            for k, v in info_fields.items():
                df[k] = v

            df["Symbol"] = ticker
            df = df.reset_index().rename(columns={"index": "Date"})
            
            cols = ["Date", "Symbol"] + [c for c in df.columns if c not in ["Date", "Symbol"]]
            df = df[cols]

            all_data.append(df)
            print(f"[{i}/{len(tickers)}] Collected variables for {ticker}")

        except Exception as e:
            print(f"[{i}/{len(tickers)}] Error fetching variables for {ticker}: {e}")

    variables = pd.concat(all_data, ignore_index=True)
    return variables

variables = calculate_variables(tickers)
# Out:
# [1/503] Collected variables for A
# [2/503] Collected variables for AAPL
# [3/503] Collected variables for ABBV
# [4/503] Collected variables for ABNB
# [5/503] Collected variables for ABT
# [6/503] Collected variables for ACGL
# [7/503] Collected variables for ACN
# [8/503] Collected variables for ADBE
# [9/503] Collected variables for ADI
# [10/503] Collected variables for ADM
# [11/503] Collected variables for ADP
# [12/503] Collected variables for ADSK
# [13/503] Collected variables for AEE
# [14/503] Collected variables for AEP
# [15/503] Collected variables for AES
# [16/503] Collected variables for AFL
# [17/503] Collected variables for AIG
# [18/503] Collected variables for AIZ
# [19/503] Collected variables for AJG
# [20/503] Collected variables for AKAM
# [21/503] Collected variables for ALB
# [22/503] Collected variables for ALGN
# [23/503] Collected variables for ALL
# [24/503] Collected variables for ALLE
# [25/503] Collected variables for AMAT
# [26/503] Collected variables for AMCR
# [27/503] Collected variables for AMD
# [28/503] Collected variables for AME
# [29/503] Collected variables for AMGN
# [30/503] Collected variables for AMP
# [31/503] Collected variables for AMT
# [32/503] Collected variables for AMZN
# [33/503] Collected variables for ANET
# [34/503] Collected variables for AON
# [35/503] Collected variables for AOS
# [36/503] Collected variables for APA
# [37/503] Collected variables for APD
# [38/503] Collected variables for APH
# [39/503] Collected variables for APO
# [40/503] Collected variables for APP
# [41/503] Collected variables for APTV
# [42/503] Collected variables for ARE
# [43/503] Collected variables for ATO
# [44/503] Collected variables for AVB
# [45/503] Collected variables for AVGO
# [46/503] Collected variables for AVY
# [47/503] Collected variables for AWK
# [48/503] Collected variables for AXON
# [49/503] Collected variables for AXP
# [50/503] Collected variables for AZO
# [51/503] Collected variables for BA
# [52/503] Collected variables for BAC
# [53/503] Collected variables for BALL
# [54/503] Collected variables for BAX
# [55/503] Collected variables for BBY
# [56/503] Collected variables for BDX
# [57/503] Collected variables for BEN
# [58/503] Collected variables for BF-B
# [59/503] Collected variables for BG
# [60/503] Collected variables for BIIB
# [61/503] Collected variables for BK
# [62/503] Collected variables for BKNG
# [63/503] Collected variables for BKR
# [64/503] Collected variables for BLDR
# [65/503] Collected variables for BLK
# [66/503] Collected variables for BMY
# [67/503] Collected variables for BR
# [68/503] Collected variables for BRK-B
# [69/503] Collected variables for BRO
# [70/503] Collected variables for BSX
# [71/503] Collected variables for BX
# [72/503] Collected variables for BXP
# [73/503] Collected variables for C
# [74/503] Collected variables for CAG
# [75/503] Collected variables for CAH
# [76/503] Collected variables for CARR
# [77/503] Collected variables for CAT
# [78/503] Collected variables for CB
# [79/503] Collected variables for CBOE
# [80/503] Collected variables for CBRE
# [81/503] Collected variables for CCI
# [82/503] Collected variables for CCL
# [83/503] Collected variables for CDNS
# [84/503] Collected variables for CDW
# [85/503] Collected variables for CEG
# [86/503] Collected variables for CF
# [87/503] Collected variables for CFG
# [88/503] Collected variables for CHD
# [89/503] Collected variables for CHRW
# [90/503] Collected variables for CHTR
# [91/503] Collected variables for CI
# [92/503] Collected variables for CINF
# [93/503] Collected variables for CL
# [94/503] Collected variables for CLX
# [95/503] Collected variables for CMCSA
# [96/503] Collected variables for CME
# [97/503] Collected variables for CMG
# [98/503] Collected variables for CMI
# [99/503] Collected variables for CMS
# [100/503] Collected variables for CNC
# [101/503] Collected variables for CNP
# [102/503] Collected variables for COF
# [103/503] Collected variables for COIN
# [104/503] Collected variables for COO
# [105/503] Collected variables for COP
# [106/503] Collected variables for COR
# [107/503] Collected variables for COST
# [108/503] Collected variables for CPAY
# [109/503] Collected variables for CPB
# [110/503] Collected variables for CPRT
# [111/503] Collected variables for CPT
# [112/503] Collected variables for CRL
# [113/503] Collected variables for CRM
# [114/503] Collected variables for CRWD
# [115/503] Collected variables for CSCO
# [116/503] Collected variables for CSGP
# [117/503] Collected variables for CSX
# [118/503] Collected variables for CTAS
# [119/503] Collected variables for CTRA
# [120/503] Collected variables for CTSH
# [121/503] Collected variables for CTVA
# [122/503] Collected variables for CVS
# [123/503] Collected variables for CVX
# [124/503] Collected variables for D
# [125/503] Collected variables for DAL
# [126/503] Collected variables for DASH
# [127/503] Collected variables for DAY
# [128/503] Collected variables for DD
# [129/503] Collected variables for DDOG
# [130/503] Collected variables for DE
# [131/503] Collected variables for DECK
# [132/503] Collected variables for DELL
# [133/503] Collected variables for DG
# [134/503] Collected variables for DGX
# [135/503] Collected variables for DHI
# [136/503] Collected variables for DHR
# [137/503] Collected variables for DIS
# [138/503] Collected variables for DLR
# [139/503] Collected variables for DLTR
# [140/503] Collected variables for DOC
# [141/503] Collected variables for DOV
# [142/503] Collected variables for DOW
# [143/503] Collected variables for DPZ
# [144/503] Collected variables for DRI
# [145/503] Collected variables for DTE
# [146/503] Collected variables for DUK
# [147/503] Collected variables for DVA
# [148/503] Collected variables for DVN
# [149/503] Collected variables for DXCM
# [150/503] Collected variables for EA
# [151/503] Collected variables for EBAY
# [152/503] Collected variables for ECL
# [153/503] Collected variables for ED
# [154/503] Collected variables for EFX
# [155/503] Collected variables for EG
# [156/503] Collected variables for EIX
# [157/503] Collected variables for EL
# [158/503] Collected variables for ELV
# [159/503] Collected variables for EME
# [160/503] Collected variables for EMN
# [161/503] Collected variables for EMR
# [162/503] Collected variables for EOG
# [163/503] Collected variables for EPAM
# [164/503] Collected variables for EQIX
# [165/503] Collected variables for EQR
# [166/503] Collected variables for EQT
# [167/503] Collected variables for ERIE
# [168/503] Collected variables for ES
# [169/503] Collected variables for ESS
# [170/503] Collected variables for ETN
# [171/503] Collected variables for ETR
# [172/503] Collected variables for EVRG
# [173/503] Collected variables for EW
# [174/503] Collected variables for EXC
# [175/503] Collected variables for EXE
# [176/503] Collected variables for EXPD
# [177/503] Collected variables for EXPE
# [178/503] Collected variables for EXR
# [179/503] Collected variables for F
# [180/503] Collected variables for FANG
# [181/503] Collected variables for FAST
# [182/503] Collected variables for FCX
# [183/503] Collected variables for FDS
# [184/503] Collected variables for FDX
# [185/503] Collected variables for FE
# [186/503] Collected variables for FFIV
# [187/503] Collected variables for FI
# [188/503] Collected variables for FICO
# [189/503] Collected variables for FIS
# [190/503] Collected variables for FITB
# [191/503] Collected variables for FOX
# [192/503] Collected variables for FOXA
# [193/503] Collected variables for FRT
# [194/503] Collected variables for FSLR
# [195/503] Collected variables for FTNT
# [196/503] Collected variables for FTV
# [197/503] Collected variables for GD
# [198/503] Collected variables for GDDY
# [199/503] Collected variables for GE
# [200/503] Collected variables for GEHC
# [201/503] Collected variables for GEN
# [202/503] Collected variables for GEV
# [203/503] Collected variables for GILD
# [204/503] Collected variables for GIS
# [205/503] Collected variables for GL
# [206/503] Collected variables for GLW
# [207/503] Collected variables for GM
# [208/503] Collected variables for GNRC
# [209/503] Collected variables for GOOG
# [210/503] Collected variables for GOOGL
# [211/503] Collected variables for GPC
# [212/503] Collected variables for GPN
# [213/503] Collected variables for GRMN
# [214/503] Collected variables for GS
# [215/503] Collected variables for GWW
# [216/503] Collected variables for HAL
# [217/503] Collected variables for HAS
# [218/503] Collected variables for HBAN
# [219/503] Collected variables for HCA
# [220/503] Collected variables for HD
# [221/503] Collected variables for HIG
# [222/503] Collected variables for HII
# [223/503] Collected variables for HLT
# [224/503] Collected variables for HOLX
# [225/503] Collected variables for HON
# [226/503] Collected variables for HOOD
# [227/503] Collected variables for HPE
# [228/503] Collected variables for HPQ
# [229/503] Collected variables for HRL
# [230/503] Collected variables for HSIC
# [231/503] Collected variables for HST
# [232/503] Collected variables for HSY
# [233/503] Collected variables for HUBB
# [234/503] Collected variables for HUM
# [235/503] Collected variables for HWM
# [236/503] Collected variables for IBKR
# [237/503] Collected variables for IBM
# [238/503] Collected variables for ICE
# [239/503] Collected variables for IDXX
# [240/503] Collected variables for IEX
# [241/503] Collected variables for IFF
# [242/503] Collected variables for INCY
# [243/503] Collected variables for INTC
# [244/503] Collected variables for INTU
# [245/503] Collected variables for INVH
# [246/503] Collected variables for IP
# [247/503] Collected variables for IPG
# [248/503] Collected variables for IQV
# [249/503] Collected variables for IR
# [250/503] Collected variables for IRM
# [251/503] Collected variables for ISRG
# [252/503] Collected variables for IT
# [253/503] Collected variables for ITW
# [254/503] Collected variables for IVZ
# [255/503] Collected variables for J
# [256/503] Collected variables for JBHT
# [257/503] Collected variables for JBL
# [258/503] Collected variables for JCI
# [259/503] Collected variables for JKHY
# [260/503] Collected variables for JNJ
# [261/503] Collected variables for JPM
# [262/503] Collected variables for K
# [263/503] Collected variables for KDP
# [264/503] Collected variables for KEY
# [265/503] Collected variables for KEYS
# [266/503] Collected variables for KHC
# [267/503] Collected variables for KIM
# [268/503] Collected variables for KKR
# [269/503] Collected variables for KLAC
# [270/503] Collected variables for KMB
# [271/503] Collected variables for KMI
# [272/503] Collected variables for KMX
# [273/503] Collected variables for KO
# [274/503] Collected variables for KR
# [275/503] Collected variables for KVUE
# [276/503] Collected variables for L
# [277/503] Collected variables for LDOS
# [278/503] Collected variables for LEN
# [279/503] Collected variables for LH
# [280/503] Collected variables for LHX
# [281/503] Collected variables for LII
# [282/503] Collected variables for LIN
# [283/503] Collected variables for LKQ
# [284/503] Collected variables for LLY
# [285/503] Collected variables for LMT
# [286/503] Collected variables for LNT
# [287/503] Collected variables for LOW
# [288/503] Collected variables for LRCX
# [289/503] Collected variables for LULU
# [290/503] Collected variables for LUV
# [291/503] Collected variables for LVS
# [292/503] Collected variables for LW
# [293/503] Collected variables for LYB
# [294/503] Collected variables for LYV
# [295/503] Collected variables for MA
# [296/503] Collected variables for MAA
# [297/503] Collected variables for MAR
# [298/503] Collected variables for MAS
# [299/503] Collected variables for MCD
# [300/503] Collected variables for MCHP
# [301/503] Collected variables for MCK
# [302/503] Collected variables for MCO
# [303/503] Collected variables for MDLZ
# [304/503] Collected variables for MDT
# [305/503] Collected variables for MET
# [306/503] Collected variables for META
# [307/503] Collected variables for MGM
# [308/503] Collected variables for MHK
# [309/503] Collected variables for MKC
# [310/503] Collected variables for MLM
# [311/503] Collected variables for MMC
# [312/503] Collected variables for MMM
# [313/503] Collected variables for MNST
# [314/503] Collected variables for MO
# [315/503] Collected variables for MOH
# [316/503] Collected variables for MOS
# [317/503] Collected variables for MPC
# [318/503] Collected variables for MPWR
# [319/503] Collected variables for MRK
# [320/503] Collected variables for MRNA
# [321/503] Collected variables for MS
# [322/503] Collected variables for MSCI
# [323/503] Collected variables for MSFT
# [324/503] Collected variables for MSI
# [325/503] Collected variables for MTB
# [326/503] Collected variables for MTCH
# [327/503] Collected variables for MTD
# [328/503] Collected variables for MU
# [329/503] Collected variables for NCLH
# [330/503] Collected variables for NDAQ
# [331/503] Collected variables for NDSN
# [332/503] Collected variables for NEE
# [333/503] Collected variables for NEM
# [334/503] Collected variables for NFLX
# [335/503] Collected variables for NI
# [336/503] Collected variables for NKE
# [337/503] Collected variables for NOC
# [338/503] Collected variables for NOW
# [339/503] Collected variables for NRG
# [340/503] Collected variables for NSC
# [341/503] Collected variables for NTAP
# [342/503] Collected variables for NTRS
# [343/503] Collected variables for NUE
# [344/503] Collected variables for NVDA
# [345/503] Collected variables for NVR
# [346/503] Collected variables for NWS
# [347/503] Collected variables for NWSA
# [348/503] Collected variables for NXPI
# [349/503] Collected variables for O
# [350/503] Collected variables for ODFL
# [351/503] Collected variables for OKE
# [352/503] Collected variables for OMC
# [353/503] Collected variables for ON
# [354/503] Collected variables for ORCL
# [355/503] Collected variables for ORLY
# [356/503] Collected variables for OTIS
# [357/503] Collected variables for OXY
# [358/503] Collected variables for PANW
# [359/503] Collected variables for PAYC
# [360/503] Collected variables for PAYX
# [361/503] Collected variables for PCAR
# [362/503] Collected variables for PCG
# [363/503] Collected variables for PEG
# [364/503] Collected variables for PEP
# [365/503] Collected variables for PFE
# [366/503] Collected variables for PFG
# [367/503] Collected variables for PG
# [368/503] Collected variables for PGR
# [369/503] Collected variables for PH
# [370/503] Collected variables for PHM
# [371/503] Collected variables for PKG
# [372/503] Collected variables for PLD
# [373/503] Collected variables for PLTR
# [374/503] Collected variables for PM
# [375/503] Collected variables for PNC
# [376/503] Collected variables for PNR
# [377/503] Collected variables for PNW
# [378/503] Collected variables for PODD
# [379/503] Collected variables for POOL
# [380/503] Collected variables for PPG
# [381/503] Collected variables for PPL
# [382/503] Collected variables for PRU
# [383/503] Collected variables for PSA
# [384/503] Collected variables for PSKY
# [385/503] Collected variables for PSX
# [386/503] Collected variables for PTC
# [387/503] Collected variables for PWR
# [388/503] Collected variables for PYPL
# [389/503] Collected variables for QCOM
# [390/503] Collected variables for RCL
# [391/503] Collected variables for REG
# [392/503] Collected variables for REGN
# [393/503] Collected variables for RF
# [394/503] Collected variables for RJF
# [395/503] Collected variables for RL
# [396/503] Collected variables for RMD
# [397/503] Collected variables for ROK
# [398/503] Collected variables for ROL
# [399/503] Collected variables for ROP
# [400/503] Collected variables for ROST
# [401/503] Collected variables for RSG
# [402/503] Collected variables for RTX
# [403/503] Collected variables for RVTY
# [404/503] Collected variables for SBAC
# [405/503] Collected variables for SBUX
# [406/503] Collected variables for SCHW
# [407/503] Collected variables for SHW
# [408/503] Collected variables for SJM
# [409/503] Collected variables for SLB
# [410/503] Collected variables for SMCI
# [411/503] Collected variables for SNA
# [412/503] Collected variables for SNPS
# [413/503] Collected variables for SO
# [414/503] Collected variables for SOLV
# [415/503] Collected variables for SPG
# [416/503] Collected variables for SPGI
# [417/503] Collected variables for SRE
# [418/503] Collected variables for STE
# [419/503] Collected variables for STLD
# [420/503] Collected variables for STT
# [421/503] Collected variables for STX
# [422/503] Collected variables for STZ
# [423/503] Collected variables for SW
# [424/503] Collected variables for SWK
# [425/503] Collected variables for SWKS
# [426/503] Collected variables for SYF
# [427/503] Collected variables for SYK
# [428/503] Collected variables for SYY
# [429/503] Collected variables for T
# [430/503] Collected variables for TAP
# [431/503] Collected variables for TDG
# [432/503] Collected variables for TDY
# [433/503] Collected variables for TECH
# [434/503] Collected variables for TEL
# [435/503] Collected variables for TER
# [436/503] Collected variables for TFC
# [437/503] Collected variables for TGT
# [438/503] Collected variables for TJX
# [439/503] Collected variables for TKO
# [440/503] Collected variables for TMO
# [441/503] Collected variables for TMUS
# [442/503] Collected variables for TPL
# [443/503] Collected variables for TPR
# [444/503] Collected variables for TRGP
# [445/503] Collected variables for TRMB
# [446/503] Collected variables for TROW
# [447/503] Collected variables for TRV
# [448/503] Collected variables for TSCO
# [449/503] Collected variables for TSLA
# [450/503] Collected variables for TSN
# [451/503] Collected variables for TT
# [452/503] Collected variables for TTD
# [453/503] Collected variables for TTWO
# [454/503] Collected variables for TXN
# [455/503] Collected variables for TXT
# [456/503] Collected variables for TYL
# [457/503] Collected variables for UAL
# [458/503] Collected variables for UBER
# [459/503] Collected variables for UDR
# [460/503] Collected variables for UHS
# [461/503] Collected variables for ULTA
# [462/503] Collected variables for UNH
# [463/503] Collected variables for UNP
# [464/503] Collected variables for UPS
# [465/503] Collected variables for URI
# [466/503] Collected variables for USB
# [467/503] Collected variables for V
# [468/503] Collected variables for VICI
# [469/503] Collected variables for VLO
# [470/503] Collected variables for VLTO
# [471/503] Collected variables for VMC
# [472/503] Collected variables for VRSK
# [473/503] Collected variables for VRSN
# [474/503] Collected variables for VRTX
# [475/503] Collected variables for VST
# [476/503] Collected variables for VTR
# [477/503] Collected variables for VTRS
# [478/503] Collected variables for VZ
# [479/503] Collected variables for WAB
# [480/503] Collected variables for WAT
# [481/503] Collected variables for WBD
# [482/503] Collected variables for WDAY
# [483/503] Collected variables for WDC
# [484/503] Collected variables for WEC
# [485/503] Collected variables for WELL
# [486/503] Collected variables for WFC
# [487/503] Collected variables for WM
# [488/503] Collected variables for WMB
# [489/503] Collected variables for WMT
# [490/503] Collected variables for WRB
# [491/503] Collected variables for WSM
# [492/503] Collected variables for WST
# [493/503] Collected variables for WTW
# [494/503] Collected variables for WY
# [495/503] Collected variables for WYNN
# [496/503] Collected variables for XEL
# [497/503] Collected variables for XOM
# [498/503] Collected variables for XYL
# [499/503] Collected variables for XYZ
# [500/503] Collected variables for YUM
# [501/503] Collected variables for ZBH
# [502/503] Collected variables for ZBRA
# [503/503] Collected variables for ZTS
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/3983459700.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   variables = pd.concat(all_data, ignore_index=True)

# %%
#DATE

print("Min Date:", variables["Date"].min())
print("Max Date:", variables["Date"].max())
variables = variables.drop(columns=["Date"])
# Out:
# Min Date: 2025-05-31 00:00:00
# Max Date: 2025-08-31 00:00:00

# %%
#METRICS

def calculate_metrics(df):
    #valuation
    df["PER"] = df["Current Price"] / df["Trailing Eps"]
    df["PEGR"] = df["PER"] / (df["Earnings Growth"] * 100)
    df["PBR"] = df["Current Price"] / df["Book Value"]
    df["DY"] = df["Dividend Yield"]
    df["EV/EBITDA"] = df["Enterprise Value"] / df["EBITDA"]
    df["P/S"] = df["Current Price"] * df["Shares Outstanding"] / df["Total Revenue"]

    #profitability
    df["ROA"] = df["Net Income"] / df["Total Assets"]
    df["NPM"] = df["Net Income"] / df["Total Revenue"]

    #financial health
    df["ICR"] = df["EBIT"] / df["Interest Expense"]
    df["FCF"] = df["Free Cash Flow"]

    df.replace([float("inf"), -float("inf")], pd.NA, inplace=True)

    cols_to_remove = [
        'Total Assets', 'Inventory', 'Total Debt', 'Net Income', 'EBITDA', 'EBIT',
        'Operating Income', 'Gross Profit', 'Total Revenue', 'Interest Expense',
        'Free Cash Flow', 'Current Price', 'Trailing Eps', 'Book Value', 'Market Cap', 
        'Enterprise Value', 'Dividend Yield', 'Shares Outstanding', 
        'Earnings Growth'
    ]
    df = df.drop(columns=[c for c in cols_to_remove if c in df.columns])

    return df

metrics = calculate_metrics(variables)
# Out:
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/2251570529.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace([float("inf"), -float("inf")], pd.NA, inplace=True)

# %%
#VARIABLES 2

def calculate_variables_2(tickers):
    all_data = []

    for i, ticker in enumerate(tickers, 1):
        try:
            t = yf.Ticker(ticker)

            is_ = t.quarterly_income_stmt.T
            is_cols = ['Net Income', 'Total Revenue']
            is_ = is_[[c for c in is_cols if c in is_.columns]]

            df = is_

            df["Symbol"] = ticker
            df = df.reset_index().rename(columns={"index": "Date"})
            
            cols = ["Date", "Symbol"] + [c for c in df.columns if c not in ["Date", "Symbol"]]
            df = df[cols]

            all_data.append(df)
            print(f"[{i}/{len(tickers)}] Collected variables for {ticker}")

        except Exception as e:
            print(f"[{i}/{len(tickers)}] Error fetching variables for {ticker}: {e}")

    variables2 = pd.concat(all_data, ignore_index=True)
    return variables2

variables2 = calculate_variables_2(tickers)
# Out:
# [1/503] Collected variables for A
# [2/503] Collected variables for AAPL
# [3/503] Collected variables for ABBV
# [4/503] Collected variables for ABNB
# [5/503] Collected variables for ABT
# [6/503] Collected variables for ACGL
# [7/503] Collected variables for ACN
# [8/503] Collected variables for ADBE
# [9/503] Collected variables for ADI
# [10/503] Collected variables for ADM
# [11/503] Collected variables for ADP
# [12/503] Collected variables for ADSK
# [13/503] Collected variables for AEE
# [14/503] Collected variables for AEP
# [15/503] Collected variables for AES
# [16/503] Collected variables for AFL
# [17/503] Collected variables for AIG
# [18/503] Collected variables for AIZ
# [19/503] Collected variables for AJG
# [20/503] Collected variables for AKAM
# [21/503] Collected variables for ALB
# [22/503] Collected variables for ALGN
# [23/503] Collected variables for ALL
# [24/503] Collected variables for ALLE
# [25/503] Collected variables for AMAT
# [26/503] Collected variables for AMCR
# [27/503] Collected variables for AMD
# [28/503] Collected variables for AME
# [29/503] Collected variables for AMGN
# [30/503] Collected variables for AMP
# [31/503] Collected variables for AMT
# [32/503] Collected variables for AMZN
# [33/503] Collected variables for ANET
# [34/503] Collected variables for AON
# [35/503] Collected variables for AOS
# [36/503] Collected variables for APA
# [37/503] Collected variables for APD
# [38/503] Collected variables for APH
# [39/503] Collected variables for APO
# [40/503] Collected variables for APP
# [41/503] Collected variables for APTV
# [42/503] Collected variables for ARE
# [43/503] Collected variables for ATO
# [44/503] Collected variables for AVB
# [45/503] Collected variables for AVGO
# [46/503] Collected variables for AVY
# [47/503] Collected variables for AWK
# [48/503] Collected variables for AXON
# [49/503] Collected variables for AXP
# [50/503] Collected variables for AZO
# [51/503] Collected variables for BA
# [52/503] Collected variables for BAC
# [53/503] Collected variables for BALL
# [54/503] Collected variables for BAX
# [55/503] Collected variables for BBY
# [56/503] Collected variables for BDX
# [57/503] Collected variables for BEN
# [58/503] Collected variables for BF-B
# [59/503] Collected variables for BG
# [60/503] Collected variables for BIIB
# [61/503] Collected variables for BK
# [62/503] Collected variables for BKNG
# [63/503] Collected variables for BKR
# [64/503] Collected variables for BLDR
# [65/503] Collected variables for BLK
# [66/503] Collected variables for BMY
# [67/503] Collected variables for BR
# [68/503] Collected variables for BRK-B
# [69/503] Collected variables for BRO
# [70/503] Collected variables for BSX
# [71/503] Collected variables for BX
# [72/503] Collected variables for BXP
# [73/503] Collected variables for C
# [74/503] Collected variables for CAG
# [75/503] Collected variables for CAH
# [76/503] Collected variables for CARR
# [77/503] Collected variables for CAT
# [78/503] Collected variables for CB
# [79/503] Collected variables for CBOE
# [80/503] Collected variables for CBRE
# [81/503] Collected variables for CCI
# [82/503] Collected variables for CCL
# [83/503] Collected variables for CDNS
# [84/503] Collected variables for CDW
# [85/503] Collected variables for CEG
# [86/503] Collected variables for CF
# [87/503] Collected variables for CFG
# [88/503] Collected variables for CHD
# [89/503] Collected variables for CHRW
# [90/503] Collected variables for CHTR
# [91/503] Collected variables for CI
# [92/503] Collected variables for CINF
# [93/503] Collected variables for CL
# [94/503] Collected variables for CLX
# [95/503] Collected variables for CMCSA
# [96/503] Collected variables for CME
# [97/503] Collected variables for CMG
# [98/503] Collected variables for CMI
# [99/503] Collected variables for CMS
# [100/503] Collected variables for CNC
# [101/503] Collected variables for CNP
# [102/503] Collected variables for COF
# [103/503] Collected variables for COIN
# [104/503] Collected variables for COO
# [105/503] Collected variables for COP
# [106/503] Collected variables for COR
# [107/503] Collected variables for COST
# [108/503] Collected variables for CPAY
# [109/503] Collected variables for CPB
# [110/503] Collected variables for CPRT
# [111/503] Collected variables for CPT
# [112/503] Collected variables for CRL
# [113/503] Collected variables for CRM
# [114/503] Collected variables for CRWD
# [115/503] Collected variables for CSCO
# [116/503] Collected variables for CSGP
# [117/503] Collected variables for CSX
# [118/503] Collected variables for CTAS
# [119/503] Collected variables for CTRA
# [120/503] Collected variables for CTSH
# [121/503] Collected variables for CTVA
# [122/503] Collected variables for CVS
# [123/503] Collected variables for CVX
# [124/503] Collected variables for D
# [125/503] Collected variables for DAL
# [126/503] Collected variables for DASH
# [127/503] Collected variables for DAY
# [128/503] Collected variables for DD
# [129/503] Collected variables for DDOG
# [130/503] Collected variables for DE
# [131/503] Collected variables for DECK
# [132/503] Collected variables for DELL
# [133/503] Collected variables for DG
# [134/503] Collected variables for DGX
# [135/503] Collected variables for DHI
# [136/503] Collected variables for DHR
# [137/503] Collected variables for DIS
# [138/503] Collected variables for DLR
# [139/503] Collected variables for DLTR
# [140/503] Collected variables for DOC
# [141/503] Collected variables for DOV
# [142/503] Collected variables for DOW
# [143/503] Collected variables for DPZ
# [144/503] Collected variables for DRI
# [145/503] Collected variables for DTE
# [146/503] Collected variables for DUK
# [147/503] Collected variables for DVA
# [148/503] Collected variables for DVN
# [149/503] Collected variables for DXCM
# [150/503] Collected variables for EA
# [151/503] Collected variables for EBAY
# [152/503] Collected variables for ECL
# [153/503] Collected variables for ED
# [154/503] Collected variables for EFX
# [155/503] Collected variables for EG
# [156/503] Collected variables for EIX
# [157/503] Collected variables for EL
# [158/503] Collected variables for ELV
# [159/503] Collected variables for EME
# [160/503] Collected variables for EMN
# [161/503] Collected variables for EMR
# [162/503] Collected variables for EOG
# [163/503] Collected variables for EPAM
# [164/503] Collected variables for EQIX
# [165/503] Collected variables for EQR
# [166/503] Collected variables for EQT
# [167/503] Collected variables for ERIE
# [168/503] Collected variables for ES
# [169/503] Collected variables for ESS
# [170/503] Collected variables for ETN
# [171/503] Collected variables for ETR
# [172/503] Collected variables for EVRG
# [173/503] Collected variables for EW
# [174/503] Collected variables for EXC
# [175/503] Collected variables for EXE
# [176/503] Collected variables for EXPD
# [177/503] Collected variables for EXPE
# [178/503] Collected variables for EXR
# [179/503] Collected variables for F
# [180/503] Collected variables for FANG
# [181/503] Collected variables for FAST
# [182/503] Collected variables for FCX
# [183/503] Collected variables for FDS
# [184/503] Collected variables for FDX
# [185/503] Collected variables for FE
# [186/503] Collected variables for FFIV
# [187/503] Collected variables for FI
# [188/503] Collected variables for FICO
# [189/503] Collected variables for FIS
# [190/503] Collected variables for FITB
# [191/503] Collected variables for FOX
# [192/503] Collected variables for FOXA
# [193/503] Collected variables for FRT
# [194/503] Collected variables for FSLR
# [195/503] Collected variables for FTNT
# [196/503] Collected variables for FTV
# [197/503] Collected variables for GD
# [198/503] Collected variables for GDDY
# [199/503] Collected variables for GE
# [200/503] Collected variables for GEHC
# [201/503] Collected variables for GEN
# [202/503] Collected variables for GEV
# [203/503] Collected variables for GILD
# [204/503] Collected variables for GIS
# [205/503] Collected variables for GL
# [206/503] Collected variables for GLW
# [207/503] Collected variables for GM
# [208/503] Collected variables for GNRC
# [209/503] Collected variables for GOOG
# [210/503] Collected variables for GOOGL
# [211/503] Collected variables for GPC
# [212/503] Collected variables for GPN
# [213/503] Collected variables for GRMN
# [214/503] Collected variables for GS
# [215/503] Collected variables for GWW
# [216/503] Collected variables for HAL
# [217/503] Collected variables for HAS
# [218/503] Collected variables for HBAN
# [219/503] Collected variables for HCA
# [220/503] Collected variables for HD
# [221/503] Collected variables for HIG
# [222/503] Collected variables for HII
# [223/503] Collected variables for HLT
# [224/503] Collected variables for HOLX
# [225/503] Collected variables for HON
# [226/503] Collected variables for HOOD
# [227/503] Collected variables for HPE
# [228/503] Collected variables for HPQ
# [229/503] Collected variables for HRL
# [230/503] Collected variables for HSIC
# [231/503] Collected variables for HST
# [232/503] Collected variables for HSY
# [233/503] Collected variables for HUBB
# [234/503] Collected variables for HUM
# [235/503] Collected variables for HWM
# [236/503] Collected variables for IBKR
# [237/503] Collected variables for IBM
# [238/503] Collected variables for ICE
# [239/503] Collected variables for IDXX
# [240/503] Collected variables for IEX
# [241/503] Collected variables for IFF
# [242/503] Collected variables for INCY
# [243/503] Collected variables for INTC
# [244/503] Collected variables for INTU
# [245/503] Collected variables for INVH
# [246/503] Collected variables for IP
# [247/503] Collected variables for IPG
# [248/503] Collected variables for IQV
# [249/503] Collected variables for IR
# [250/503] Collected variables for IRM
# [251/503] Collected variables for ISRG
# [252/503] Collected variables for IT
# [253/503] Collected variables for ITW
# [254/503] Collected variables for IVZ
# [255/503] Collected variables for J
# [256/503] Collected variables for JBHT
# [257/503] Collected variables for JBL
# [258/503] Collected variables for JCI
# [259/503] Collected variables for JKHY
# [260/503] Collected variables for JNJ
# [261/503] Collected variables for JPM
# [262/503] Collected variables for K
# [263/503] Collected variables for KDP
# [264/503] Collected variables for KEY
# [265/503] Collected variables for KEYS
# [266/503] Collected variables for KHC
# [267/503] Collected variables for KIM
# [268/503] Collected variables for KKR
# [269/503] Collected variables for KLAC
# [270/503] Collected variables for KMB
# [271/503] Collected variables for KMI
# [272/503] Collected variables for KMX
# [273/503] Collected variables for KO
# [274/503] Collected variables for KR
# [275/503] Collected variables for KVUE
# [276/503] Collected variables for L
# [277/503] Collected variables for LDOS
# [278/503] Collected variables for LEN
# [279/503] Collected variables for LH
# [280/503] Collected variables for LHX
# [281/503] Collected variables for LII
# [282/503] Collected variables for LIN
# [283/503] Collected variables for LKQ
# [284/503] Collected variables for LLY
# [285/503] Collected variables for LMT
# [286/503] Collected variables for LNT
# [287/503] Collected variables for LOW
# [288/503] Collected variables for LRCX
# [289/503] Collected variables for LULU
# [290/503] Collected variables for LUV
# [291/503] Collected variables for LVS
# [292/503] Collected variables for LW
# [293/503] Collected variables for LYB
# [294/503] Collected variables for LYV
# [295/503] Collected variables for MA
# [296/503] Collected variables for MAA
# [297/503] Collected variables for MAR
# [298/503] Collected variables for MAS
# [299/503] Collected variables for MCD
# [300/503] Collected variables for MCHP
# [301/503] Collected variables for MCK
# [302/503] Collected variables for MCO
# [303/503] Collected variables for MDLZ
# [304/503] Collected variables for MDT
# [305/503] Collected variables for MET
# [306/503] Collected variables for META
# [307/503] Collected variables for MGM
# [308/503] Collected variables for MHK
# [309/503] Collected variables for MKC
# [310/503] Collected variables for MLM
# [311/503] Collected variables for MMC
# [312/503] Collected variables for MMM
# [313/503] Collected variables for MNST
# [314/503] Collected variables for MO
# [315/503] Collected variables for MOH
# [316/503] Collected variables for MOS
# [317/503] Collected variables for MPC
# [318/503] Collected variables for MPWR
# [319/503] Collected variables for MRK
# [320/503] Collected variables for MRNA
# [321/503] Collected variables for MS
# [322/503] Collected variables for MSCI
# [323/503] Collected variables for MSFT
# [324/503] Collected variables for MSI
# [325/503] Collected variables for MTB
# [326/503] Collected variables for MTCH
# [327/503] Collected variables for MTD
# [328/503] Collected variables for MU
# [329/503] Collected variables for NCLH
# [330/503] Collected variables for NDAQ
# [331/503] Collected variables for NDSN
# [332/503] Collected variables for NEE
# [333/503] Collected variables for NEM
# [334/503] Collected variables for NFLX
# [335/503] Collected variables for NI
# [336/503] Collected variables for NKE
# [337/503] Collected variables for NOC
# [338/503] Collected variables for NOW
# [339/503] Collected variables for NRG
# [340/503] Collected variables for NSC
# [341/503] Collected variables for NTAP
# [342/503] Collected variables for NTRS
# [343/503] Collected variables for NUE
# [344/503] Collected variables for NVDA
# [345/503] Collected variables for NVR
# [346/503] Collected variables for NWS
# [347/503] Collected variables for NWSA
# [348/503] Collected variables for NXPI
# [349/503] Collected variables for O
# [350/503] Collected variables for ODFL
# [351/503] Collected variables for OKE
# [352/503] Collected variables for OMC
# [353/503] Collected variables for ON
# [354/503] Collected variables for ORCL
# [355/503] Collected variables for ORLY
# [356/503] Collected variables for OTIS
# [357/503] Collected variables for OXY
# [358/503] Collected variables for PANW
# [359/503] Collected variables for PAYC
# [360/503] Collected variables for PAYX
# [361/503] Collected variables for PCAR
# [362/503] Collected variables for PCG
# [363/503] Collected variables for PEG
# [364/503] Collected variables for PEP
# [365/503] Collected variables for PFE
# [366/503] Collected variables for PFG
# [367/503] Collected variables for PG
# [368/503] Collected variables for PGR
# [369/503] Collected variables for PH
# [370/503] Collected variables for PHM
# [371/503] Collected variables for PKG
# [372/503] Collected variables for PLD
# [373/503] Collected variables for PLTR
# [374/503] Collected variables for PM
# [375/503] Collected variables for PNC
# [376/503] Collected variables for PNR
# [377/503] Collected variables for PNW
# [378/503] Collected variables for PODD
# [379/503] Collected variables for POOL
# [380/503] Collected variables for PPG
# [381/503] Collected variables for PPL
# [382/503] Collected variables for PRU
# [383/503] Collected variables for PSA
# [384/503] Collected variables for PSKY
# [385/503] Collected variables for PSX
# [386/503] Collected variables for PTC
# [387/503] Collected variables for PWR
# [388/503] Collected variables for PYPL
# [389/503] Collected variables for QCOM
# [390/503] Collected variables for RCL
# [391/503] Collected variables for REG
# [392/503] Collected variables for REGN
# [393/503] Collected variables for RF
# [394/503] Collected variables for RJF
# [395/503] Collected variables for RL
# [396/503] Collected variables for RMD
# [397/503] Collected variables for ROK
# [398/503] Collected variables for ROL
# [399/503] Collected variables for ROP
# [400/503] Collected variables for ROST
# [401/503] Collected variables for RSG
# [402/503] Collected variables for RTX
# [403/503] Collected variables for RVTY
# [404/503] Collected variables for SBAC
# [405/503] Collected variables for SBUX
# [406/503] Collected variables for SCHW
# [407/503] Collected variables for SHW
# [408/503] Collected variables for SJM
# [409/503] Collected variables for SLB
# [410/503] Collected variables for SMCI
# [411/503] Collected variables for SNA
# [412/503] Collected variables for SNPS
# [413/503] Collected variables for SO
# [414/503] Collected variables for SOLV
# [415/503] Collected variables for SPG
# [416/503] Collected variables for SPGI
# [417/503] Collected variables for SRE
# [418/503] Collected variables for STE
# [419/503] Collected variables for STLD
# [420/503] Collected variables for STT
# [421/503] Collected variables for STX
# [422/503] Collected variables for STZ
# [423/503] Collected variables for SW
# [424/503] Collected variables for SWK
# [425/503] Collected variables for SWKS
# [426/503] Collected variables for SYF
# [427/503] Collected variables for SYK
# [428/503] Collected variables for SYY
# [429/503] Collected variables for T
# [430/503] Collected variables for TAP
# [431/503] Collected variables for TDG
# [432/503] Collected variables for TDY
# [433/503] Collected variables for TECH
# [434/503] Collected variables for TEL
# [435/503] Collected variables for TER
# [436/503] Collected variables for TFC
# [437/503] Collected variables for TGT
# [438/503] Collected variables for TJX
# [439/503] Collected variables for TKO
# [440/503] Collected variables for TMO
# [441/503] Collected variables for TMUS
# [442/503] Collected variables for TPL
# [443/503] Collected variables for TPR
# [444/503] Collected variables for TRGP
# [445/503] Collected variables for TRMB
# [446/503] Collected variables for TROW
# [447/503] Collected variables for TRV
# [448/503] Collected variables for TSCO
# [449/503] Collected variables for TSLA
# [450/503] Collected variables for TSN
# [451/503] Collected variables for TT
# [452/503] Collected variables for TTD
# [453/503] Collected variables for TTWO
# [454/503] Collected variables for TXN
# [455/503] Collected variables for TXT
# [456/503] Collected variables for TYL
# [457/503] Collected variables for UAL
# [458/503] Collected variables for UBER
# [459/503] Collected variables for UDR
# [460/503] Collected variables for UHS
# [461/503] Collected variables for ULTA
# [462/503] Collected variables for UNH
# [463/503] Collected variables for UNP
# [464/503] Collected variables for UPS
# [465/503] Collected variables for URI
# [466/503] Collected variables for USB
# [467/503] Collected variables for V
# [468/503] Collected variables for VICI
# [469/503] Collected variables for VLO
# [470/503] Collected variables for VLTO
# [471/503] Collected variables for VMC
# [472/503] Collected variables for VRSK
# [473/503] Collected variables for VRSN
# [474/503] Collected variables for VRTX
# [475/503] Collected variables for VST
# [476/503] Collected variables for VTR
# [477/503] Collected variables for VTRS
# [478/503] Collected variables for VZ
# [479/503] Collected variables for WAB
# [480/503] Collected variables for WAT
# [481/503] Collected variables for WBD
# [482/503] Collected variables for WDAY
# [483/503] Collected variables for WDC
# [484/503] Collected variables for WEC
# [485/503] Collected variables for WELL
# [486/503] Collected variables for WFC
# [487/503] Collected variables for WM
# [488/503] Collected variables for WMB
# [489/503] Collected variables for WMT
# [490/503] Collected variables for WRB
# [491/503] Collected variables for WSM
# [492/503] Collected variables for WST
# [493/503] Collected variables for WTW
# [494/503] Collected variables for WY
# [495/503] Collected variables for WYNN
# [496/503] Collected variables for XEL
# [497/503] Collected variables for XOM
# [498/503] Collected variables for XYL
# [499/503] Collected variables for XYZ
# [500/503] Collected variables for YUM
# [501/503] Collected variables for ZBH
# [502/503] Collected variables for ZBRA
# [503/503] Collected variables for ZTS

# %%
#DATE 2

variables2 = variables2.drop(columns=["Date"])

# %%
#METRICS 2

def calculate_metrics_2(df):
    #growth
    df["RGR"] = df.groupby("Symbol")["Total Revenue"].pct_change()
    df["EGR"] = df.groupby("Symbol")["Net Income"].pct_change()

    df.replace([float("inf"), -float("inf")], pd.NA, inplace=True)

    cols_to_remove = ['Total Revenue', 'Net Income']
    df = df.drop(columns=[c for c in cols_to_remove if c in df.columns])

    return df

metrics2 = calculate_metrics_2(variables2)
# Out:
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/3141918789.py:5: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["RGR"] = df.groupby("Symbol")["Total Revenue"].pct_change()
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/3141918789.py:6: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df["EGR"] = df.groupby("Symbol")["Net Income"].pct_change()

# %%
#MERGE

def last_nonzero(df, group_col, value_cols):
    result = []
    for symbol, group in df.groupby(group_col):
        group = group.sort_index()
        non_zero_mask = (group[value_cols] != 0).any(axis=1)
        non_zero_rows = group[non_zero_mask]
        if not non_zero_rows.empty:
            result.append(non_zero_rows.tail(1))
        else:
            result.append(group.tail(1))
            
    return pd.concat(result).reset_index(drop=True)

value_cols = ["RGR", "EGR"] 
all_metrics = pd.merge(metrics, metrics2, on="Symbol", how="inner")
all_metrics = last_nonzero(all_metrics, "Symbol", value_cols)
all_metrics = all_metrics.groupby("Symbol").tail(1).reset_index(drop=True)

# %%
#MISSING VALUES

missing_per_symbol = all_metrics.isna().groupby(all_metrics["Symbol"]).sum().sum(axis=1)
missing_per_symbol = missing_per_symbol[missing_per_symbol > 0]

print("Missing Values per Symbol:")
for symbol, count in missing_per_symbol.sort_values(ascending=False).items():
    print(f"- {symbol}: {count}")

missing_per_column = all_metrics.isna().sum()
missing_per_column = missing_per_column[missing_per_column > 0]

print("\nMissing Values per Column:")
for col, count in missing_per_column.sort_values(ascending=False).items():
    print(f"- {col}: {count}")
# Out:
# Missing Values per Symbol:
# - AZO: 7
# - JBL: 6
# - MU: 6
# - FDS: 6
# - CTAS: 6
# - COST: 6
# - ACN: 6
# - LEN: 6
# - TTWO: 3
# - COF: 3
# - DASH: 3
# - RF: 3
# - CRWD: 2
# - EPAM: 2
# - PNC: 2
# - EW: 2
# - ERIE: 2
# - RJF: 2
# - PRU: 2
# - CPRT: 2
# - SCHW: 2
# - DAY: 2
# - SYF: 2
# - CSGP: 2
# - STT: 2
# - SOLV: 2
# - FDX: 2
# - INTC: 2
# - MNST: 2
# - KEY: 2
# - JPM: 2
# - ISRG: 2
# - MRNA: 2
# - MS: 2
# - MTB: 2
# - INCY: 2
# - FFIV: 2
# - ABNB: 2
# - HOOD: 2
# - HBAN: 2
# - GS: 2
# - NTRS: 2
# - FITB: 2
# - PFG: 2
# - PLTR: 2
# - LULU: 2
# - CNC: 2
# - TTD: 2
# - WDC: 2
# - C: 2
# - ALGN: 2
# - WBD: 2
# - BRK-B: 2
# - BK: 2
# - BAC: 2
# - AIG: 2
# - BA: 2
# - AXP: 2
# - VRTX: 2
# - USB: 2
# - ANET: 2
# - ULTA: 2
# - WFC: 2
# - BX: 2
# - XYZ: 2
# - CBRE: 2
# - ACGL: 2
# - CMG: 2
# - ADSK: 2
# - CFG: 2
# - TDY: 2
# - TFC: 2
# - MPWR: 1
# - NVR: 1
# - NRG: 1
# - MET: 1
# - NOW: 1
# - NKE: 1
# - MGM: 1
# - MHK: 1
# - NFLX: 1
# - MOS: 1
# - VTRS: 1
# - MOH: 1
# - NCLH: 1
# - WAT: 1
# - WSM: 1
# - MTD: 1
# - NWSA: 1
# - WRB: 1
# - WDAY: 1
# - NWS: 1
# - UAL: 1
# - ON: 1
# - ORLY: 1
# - TAP: 1
# - SYK: 1
# - TECH: 1
# - SWK: 1
# - SW: 1
# - TPL: 1
# - TPR: 1
# - TRMB: 1
# - STZ: 1
# - MCHP: 1
# - SNPS: 1
# - SMCI: 1
# - SJM: 1
# - TROW: 1
# - RMD: 1
# - PYPL: 1
# - PTC: 1
# - PSKY: 1
# - TRV: 1
# - TSLA: 1
# - POOL: 1
# - PODD: 1
# - TYL: 1
# - PGR: 1
# - TDG: 1
# - UBER: 1
# - PCAR: 1
# - PANW: 1
# - OTIS: 1
# - AAPL: 1
# - HSIC: 1
# - LYV: 1
# - L: 1
# - CCL: 1
# - CDNS: 1
# - CHRW: 1
# - CHTR: 1
# - CI: 1
# - CINF: 1
# - COIN: 1
# - COO: 1
# - CPAY: 1
# - CPB: 1
# - CRL: 1
# - CRM: 1
# - DDOG: 1
# - DECK: 1
# - DHI: 1
# - DLTR: 1
# - DOW: 1
# - CB: 1
# - BSX: 1
# - BLDR: 1
# - AMCR: 1
# - ADBE: 1
# - AES: 1
# - AFL: 1
# - AIZ: 1
# - AKAM: 1
# - ALB: 1
# - ALL: 1
# - AMD: 1
# - BIIB: 1
# - AMP: 1
# - AMZN: 1
# - APP: 1
# - APTV: 1
# - ARE: 1
# - AXON: 1
# - BAX: 1
# - DRI: 1
# - DVA: 1
# - DXCM: 1
# - IQV: 1
# - HAS: 1
# - HIG: 1
# - HOLX: 1
# - HPE: 1
# - HUM: 1
# - IDXX: 1
# - INTU: 1
# - IR: 1
# - GNRC: 1
# - IRM: 1
# - IT: 1
# - IVZ: 1
# - KEYS: 1
# - KHC: 1
# - KMI: 1
# - KMX: 1
# - GRMN: 1
# - GL: 1
# - EA: 1
# - F: 1
# - ECL: 1
# - EG: 1
# - EL: 1
# - ELV: 1
# - EME: 1
# - EXE: 1
# - EXPD: 1
# - FI: 1
# - GIS: 1
# - FICO: 1
# - FIS: 1
# - FSLR: 1
# - FTNT: 1
# - GD: 1
# - GDDY: 1
# - GEV: 1
# - ZBRA: 1
#
# Missing Values per Column:
# - DY: 96
# - ICR: 85
# - EV/EBITDA: 58
# - PEGR: 44
# - P/S: 8
# - ROA: 8
# - NPM: 8
# - FCF: 8

# %%
#HANDLE MISSING VALUES

#stocks
symbols_to_drop = ["AZO", "JBL", "ACN", "LEN", "COST", "FDS", "MU", "CTAS"]
all_metrics = all_metrics[~all_metrics["Symbol"].isin(symbols_to_drop)].reset_index(drop=True)

#variables
sp500["Symbol"] = sp500["Symbol"].replace(ticker_map)
sp500 = sp500[["Symbol", "GICS Sector"]]
all_metrics = all_metrics.merge(sp500, on="Symbol", how="left")

all_metrics['DY'] = all_metrics['DY'].fillna(0)

all_metrics['ICR'] = all_metrics.groupby('GICS Sector')['ICR'].transform(
    lambda x: x.fillna(x.median())
)
all_metrics['ICR'] = all_metrics['ICR'].fillna(all_metrics['ICR'].median())

all_metrics['EV/EBITDA'] = all_metrics.groupby('GICS Sector')['EV/EBITDA'].transform(
    lambda x: x.fillna(x.median())
)
all_metrics['EV/EBITDA'] = all_metrics['EV/EBITDA'].fillna(all_metrics['EV/EBITDA'].median())

all_metrics['PEGR'] = all_metrics.groupby('GICS Sector')['PEGR'].transform(
    lambda x: x.fillna(x.median())
)
all_metrics['PEGR'] = all_metrics['PEGR'].fillna(all_metrics['PEGR'].median())

all_metrics = all_metrics.drop(columns=['GICS Sector'])
# Out:
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())
# /var/folders/9b/b9bk135x3gd6hxg4hr0846t80000gn/T/ipykernel_21608/4135206331.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lambda x: x.fillna(x.median())

# %%
#SAVE

all_metrics.to_csv("../Data/fundamental.csv", index=False)
